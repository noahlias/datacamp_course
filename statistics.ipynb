# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from math import pi
plt.rcParams["figure.figsize"] = (4,4)

# %%
d = np.linspace(0, 2*np.pi, 50)
x = np.sin(d)
y = np.cos(d)
plt.plot(x, y)
plt.show()

# %%
len(d)
# Out:
# 50

# %%
points = 500
angle = (3-5**(1/2))*pi
e = np.arange(1,points+1)* angle
x = np.sin(e)
y = np.cos(e)
plt.scatter(x*e, y*e )
plt.show()

# %%
plt.scatter(x*e, y*e)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
plt.scatter(x*e, y*e, alpha=0.5,s=200, c='#006400')
plt.show()

# %%
plt.scatter(x*e, y*e, alpha=0.5,s=200, marker='*')
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x*e, y*e, alpha=0.5,s=17,c='yellow')
ax.set_facecolor('#8b008b')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
plt.show()

# %%
points = 1000
angle = 2
e = np.arange(1,points+1)* angle
x = np.sin(e)
y = np.cos(e)
fig, ax = plt.subplots()
ax.scatter(x*e, y*e, alpha=0.5,s=17,c='yellow')
ax.set_facecolor('#8b008b')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
plt.show()

# %%
points = 2000
angle = 13*pi/180
e = np.arange(1,points+1)* angle
x = np.sin(e)
y = np.cos(e)
fig, ax = plt.subplots()
ax.scatter(x*e, y*e, alpha=0.1,s=80,c='#FF00FF')
ax.set_facecolor('white')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
plt.show()
